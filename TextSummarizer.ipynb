# %%
## installation
# see https://twitter.com/huggingface/status/1242512382800400384
# details https://github.com/huggingface/transformers/releases/tag/v2.6.0
# !pip install transformers --upgrade
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.55.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %%
from transformers import pipeline
import requests
import pprint
import time
pp = pprint.PrettyPrinter(indent=14)

# %%
## documentation for summarizer: https://huggingface.co/transformers/main_classes/pipelines.html#summarizationpipeline
# summarize with BART
summarizer_bart = pipeline(task='summarization', model="bart-large-cnn")
# summarize with T5
summarizer_t5 = pipeline(task='summarization', model="t5-large") # options: ‘t5-small’, ‘t5-base’, ‘t5-large’, ‘t5-3b’, ‘t5-11b’
#for T5 you can chose the size of the model. Everything above t5-base is very slow, even on GPU or TPU.
# Out:
# Device set to use cpu

# %%
## summarize book with T5 model
t0 = time.time() # timer
summary_manifesto_t5 = summarizer_t5(communist_manifesto_cl, min_length=150, max_length=500) # change min_ and max_length for different output
print("Summarization took " + str(round((time.time() - t0) / 60, 2)) + " minutes.") # timer
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cuda:0
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# /tmp/ipython-input-2360964475.py in <cell line: 0>()
# ----> 1 summarizer_t5 = pipeline("summarization", model="t5-small", device=0)
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1208         kwargs["processor"] = processor
#    1209
# -> 1210     return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text2text_generation.py in __init__(self, *args, **kwargs)
#      83
#      84     def __init__(self, *args, **kwargs):
# ---> 85         super().__init__(*args, **kwargs)
#      86
#      87         self.check_model_type(
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in __init__(self, model, tokenizer, feature_extractor, image_processor, processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#    1041             and hf_device_map is None
#    1042         ):
# -> 1043             self.model.to(self.device)
#    1044
#    1045         # If it's a generation pipeline and the model can generate:
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py in to(self, *args, **kwargs)
#    4339                     " `dtype` by passing the correct `torch_dtype` argument."
#    4340                 )
# -> 4341         return super().to(*args, **kwargs)
#    4342
#    4343     def half(self, *args):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1367                     raise
#    1368
# -> 1369         return self._apply(convert)
#    1370
#    1371     def register_full_backward_pre_hook(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     926         if recurse:
#     927             for module in self.children():
# --> 928                 module._apply(fn)
#     929
#     930         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _apply(self, fn, recurse)
#     953             # `with torch.no_grad():`
#     954             with torch.no_grad():
# --> 955                 param_applied = fn(param)
#     956             p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     957
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in convert(t)
#    1353                         memory_format=convert_to_format,
#    1354                     )
# -> 1355                 return t.to(
#    1356                     device,
#    1357                     dtype if t.is_floating_point() or t.is_complex() else None,
#
# AcceleratorError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
pp.pprint(summary_manifesto_t5[0]['summary_text'])
# Out:
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# /tmp/ipython-input-4054298184.py in <cell line: 0>()
#       1 ## summarize book with BART model
#       2 t0 = time.time() # timer
# ----> 3 summary_manifesto_bart = summarizer_bart(communist_manifesto_cl, min_length=150, max_length=500) # change min_ and max_length for different output
#       4 print("Summarization took " + str(round((time.time() - t0) / 60, 2)) + " minutes.")
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     301               ids of the summary.
#     302         """
# --> 303         return super().__call__(*args, **kwargs)
#     304
#     305     def check_inputs(self, input_length: int, min_length: int, max_length: int) -> bool:
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     189         """
#     190
# --> 191         result = super().__call__(*args, **kwargs)
#     192         if (
#     193             isinstance(args[0], list)
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1456             )
#    1457         else:
# -> 1458             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1459
#    1460     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1463     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1464         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1465         model_outputs = self.forward(model_inputs, **forward_params)
#    1466         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1467         return outputs
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1362                 inference_context = self.get_inference_context()
#    1363                 with inference_context():
# -> 1364                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
#    1365                     model_outputs = self._forward(model_inputs, **forward_params)
#    1366                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in _ensure_tensor_on_device(self, inputs, device)
#    1266             return {name: self._ensure_tensor_on_device(tensor, device) for name, tensor in inputs.items()}
#    1267         elif isinstance(inputs, UserDict):
# -> 1268             return UserDict({name: self._ensure_tensor_on_device(tensor, device) for name, tensor in inputs.items()})
#    1269         elif isinstance(inputs, list):
#    1270             return [self._ensure_tensor_on_device(item, device) for item in inputs]
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in _ensure_tensor_on_device(self, inputs, device)
#    1272             return tuple([self._ensure_tensor_on_device(item, device) for item in inputs])
#    1273         elif isinstance(inputs, torch.Tensor):
# -> 1274             return inputs.to(device)
#    1275         else:
#    1276             return inputs
#
# AcceleratorError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
